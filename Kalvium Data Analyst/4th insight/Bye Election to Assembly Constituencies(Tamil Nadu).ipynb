# %%
from bs4 import BeautifulSoup
import requests
url = 'https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS22233.htm'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=7" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="300" http-equiv="refresh"/>
# <!-- Bootstrap CSS -->
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <link href="css/custom.css" rel="stylesheet"/>
# <link href="css/responsive.css" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet"/>
# <link href="img/icons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>Election Commission of India</title>
# <script>!function(a){var e="https://s.go-mpulse.net/boomerang/",t="addEventListener";if("False"=="True")a.BOOMR_config=a.BOOMR_config||{},a.BOOMR_config.PageParams=a.BOOMR_config.PageParams||{},a.BOOMR_config.PageParams.pci=!0,e="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="C8JDA-BHWH8-9MQ5M-HKZCP-GH7SB",function(){function n(e){a.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!a.BOOMR||!a.BOOMR.version&&!a.BOOMR.snippetExecuted){a.BOOMR=a.BOOMR||{},a.BOOMR.snippetExecuted=!0;var i,_,o,r=document.createElement("iframe");if(a[t])a[t]("load",n,!1);else if(a.attachEvent)a.attachEvent("onload",n);r.src="javascript:void(0)",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="width:0;height:0;border:0;display:none;",o=document.getElementsByTagName("script")[0],o.parentNode.insertBefore(r,o);try{_=r.contentWindow.document}catch(O){i=document.domain,r.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",_=r.contentWindow.document}_.open()._l=function(){var a=this.createElement("script");if(i)this.domain=i;a.id="boomr-if-as",a.src=e+"C8JDA-BHWH8-9MQ5M-HKZCP-GH7SB",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(a)},_.write("<bo"+'dy onload="document._l();">'),_.close()}}(),"".length>0)if(a&&"performance"in a&&a.performance&&"function"==typeof a.performance.setResourceTimingBufferSize)a.performance.setResourceTimingBufferSize();!function(){if(BOOMR=a.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var e=""=="true"?1:0,t="",n="m6z5hqjrftbnezubptda-f-3990b647b-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,_={"ak.v":"37","ak.cp":"1109753","ak.ai":parseInt("537121",10),"ak.ol":"0","ak.cr":58,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"af29700","ak.r":33499,"ak.a2":e,"ak.m":"b","ak.n":"ff","ak.bpcip":"103.179.211.0","ak.cport":49723,"ak.gh":"49.44.194.206","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1719762118","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"86","ak.dpoabenc":"","ak.tf":i};if(""!==t)_["ak.ruds"]=t;var o={i:!1,av:function(e){var t="http.initiator";if(e&&(!e[t]||"spa_hard"===e[t]))_["ak.feo"]=void 0!==a.aFeoApplied?1:0,BOOMR.addVar(_)},rv:function(){var a=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(a)}};BOOMR.plugins.AK={akVars:_,akDNSPreFetchDomain:n,init:function(){if(!o.i){var a=BOOMR.subscribe;a("before_beacon",o.av,null,null),a("onbeacon",o.rv,null,null),o.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
# <body>
# <header class="header">
# <div class="logo-search">
# <div class="logo"><a href="index.htm"><img alt="" src="img/eci-logo.png"/></a></div>
# <div class="lft-menu">
# <ul>
# <li><a href="index.htm"><span><img alt="" src="img/icons/home.png"/></span> Home</a></li>
# <li><a href="./hi/ConstituencywiseS22233.htm">Hindi <span><img alt="" src="img/icons/language.png"/></span></a></li>
# <!--<li><a href='search.htm'>Search <span><img src='img/icons/search.png' alt=''></span></a></li>-->
# <li><a href="" onclick="window.location.href=window.location.href">Refresh <span><img alt="" src="img/icons/refresh.png"/></span></a></li>
# </ul>
# </div>
# </div>
# </header>
# <div class="dis-info">
# <div class="container-fluid">
# <div class="d-flex align-items-center">
# <h6 class="mb-0 mx-2">Disclaimer:</h6>
# <p class="mb-0"> ECI is displaying the information as being filled in the system by the Returning Officers from their respective Counting Centres.The final data for each AC/PC will be shared in Form-20.</p>
# </div>
# </div>
# </div><!-- End of dis-info Div -->
# <main class="inner-content">
# <div class="container-fluid">
# <div class="page-title">
# <h1>
# <div>Bye Election to Assembly Constituencies: Results June-2024 </div>
# </h1>
# <h2>Assembly Constituency <span> 233 - Vilavancode<strong> (Tamil Nadu)</strong></span> </h2>
# </div>
# <!-- End of middle-head Div -->
# <div class="middle-head">
# <div class="roundBtn"> </div>
# <div class="round-status">Status as on Round, <span>22</span>/22 </div>
# <div class="switch-list">
# <ul>
# <li> <a href="RoundwiseS22233.htm?ac=233"><img alt="" src="img/icons/roundwise-35.png" title="Round Wise EVM Votes"/></a></li>
# <li><a href="candidateswise-S22233.htm"><img alt="" src="img/icons/user-ifo.png" title="Constituency Wise Candidate View"/></a></li>
# <li><a href="#"><img alt="" src="img/icons/tab-info.png" title="Constituency Wise Table View"/></a></li>
# </ul>
# </div>
# </div>
# <div class="custom-table">
# <div class="table-responsive">
# <table class="table table-striped table-bordered">
# <thead>
# <tr>
# <th>S.N.</th>
# <th style="text-align: left;">Candidate</th>
# <th style="text-align: left;">Party</th>
# <th>EVM Votes </th>
# <th>Postal Votes</th>
# <th>Total Votes</th>
# <th>% of Votes</th>
# </tr>
# </thead>
# <tbody>
# <tr><td>1</td><td align="left">THARAHAI CUTHBERT</td><td align="left">Indian National Congress</td><td>89387</td><td>1667</td><td>91054</td><td>57.71</td></tr> <tr><td>2</td><td align="left">NANTHINI V S</td><td align="left">Bharatiya Janata Party</td><td>50008</td><td>872</td><td>50880</td><td>32.25</td></tr> <tr><td>3</td><td align="left">RANI U</td><td align="left">All India Anna Dravida Munnetra Kazhagam</td><td>5178</td><td>89</td><td>5267</td><td>3.34</td></tr> <tr><td>4</td><td align="left">JEMINI R</td><td align="left">Naam Tamilar Katchi</td><td>7929</td><td>221</td><td>8150</td><td>5.17</td></tr> <tr><td>5</td><td align="left">OM PRAKASH A</td><td align="left">Independent</td><td>164</td><td>3</td><td>167</td><td>0.11</td></tr> <tr><td>6</td><td align="left">THANGAPPAN C</td><td align="left">Independent</td><td>105</td><td>5</td><td>110</td><td>0.07</td></tr> <tr><td>7</td><td align="left">MANAVAI KANNAN M</td><td align="left">Independent</td><td>175</td><td>3</td><td>178</td><td>0.11</td></tr> <tr><td>8</td><td align="left">MOHAN KUMAR M</td><td align="left">Independent</td><td>609</td><td>8</td><td>617</td><td>0.39</td></tr> <tr><td>9</td><td align="left">VIJAYA KUMAR C</td><td align="left">Independent</td><td>142</td><td>2</td><td>144</td><td>0.09</td></tr> <tr><td>10</td><td align="left">SHAJIN R</td><td align="left">Independent</td><td>285</td><td>5</td><td>290</td><td>0.18</td></tr> <tr><td>11</td><td align="left">NOTA</td><td align="left">None of the Above</td><td>892</td><td>27</td><td>919</td><td>0.58</td></tr>
# </tbody>
# <tfoot>
# <tr>
# <th></th>
# <th style="text-align: left;">Total</th>
# <th> </th>
# <th>154874</th>
# <th>2902</th>
# <th>157776</th>
# <th></th>
# </tr>
# </tfoot>
# </table>
# </div>
# </div>
# </div><!-- End of container-fluid Div -->
# </main>
# <footer class="footer">
# <div class="foot-info">
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-6 col-12">
# <h6 class="mb-1">Download Voter helpline app to see results on mobile</h6>
# <div class="sm-text">Last Updated at 08:55 am On 05/06/2024</div>
# </div>
# <div class="col-md-6 col-12">
# <ul class="d-flex align-items-center items-end">
# <li><a href="https://play.google.com/store/apps/details?id=com.eci.citizen" target="_blank"><img alt="" src="img/icons/android.png"/></a></li>
# <li><a href="https://apps.apple.com/in/app/voter-helpline/id1456535004" target="_blank"><img alt="" src="img/icons/apple.png"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <!-- Optional JavaScript; choose one of the two! -->
# <script src="js/jquery-3.6.0.min.js" type="text/javascript"></script>
# <!-- Option 1: Bootstrap Bundle with Popper -->
# <script src="js/bootstrap.bundle.min.js" type="text/javascript"></script>
# <!-- Option 3: Custom jQuery Lab -->
# <script src="js/custom-jQuery.js" type="text/javascript"></script>
# <script>
#     $(document).ready(function () {
#       // Event for pushed the video
#       $('#roundSlider').carousel({
#         pause: true,
#         interval: false
#       });
#     });
#   </script>
# </body>
# </html>

# %%
soup.find('div', class_='page-title')
# Out:
# <div class="page-title">
# <h1>
# <div>Bye Election to Assembly Constituencies: Results June-2024 </div>
# </h1>
# <h2>Assembly Constituency <span> 233 - Vilavancode<strong> (Tamil Nadu)</strong></span> </h2>
# </div>

# %%
soup.find('table', class_='table table-striped table-bordered')
# Out:
# <table class="table table-striped table-bordered">
# <thead>
# <tr>
# <th>S.N.</th>
# <th style="text-align: left;">Candidate</th>
# <th style="text-align: left;">Party</th>
# <th>EVM Votes </th>
# <th>Postal Votes</th>
# <th>Total Votes</th>
# <th>% of Votes</th>
# </tr>
# </thead>
# <tbody>
# <tr><td>1</td><td align="left">THARAHAI CUTHBERT</td><td align="left">Indian National Congress</td><td>89387</td><td>1667</td><td>91054</td><td>57.71</td></tr> <tr><td>2</td><td align="left">NANTHINI V S</td><td align="left">Bharatiya Janata Party</td><td>50008</td><td>872</td><td>50880</td><td>32.25</td></tr> <tr><td>3</td><td align="left">RANI U</td><td align="left">All India Anna Dravida Munnetra Kazhagam</td><td>5178</td><td>89</td><td>5267</td><td>3.34</td></tr> <tr><td>4</td><td align="left">JEMINI R</td><td align="left">Naam Tamilar Katchi</td><td>7929</td><td>221</td><td>8150</td><td>5.17</td></tr> <tr><td>5</td><td align="left">OM PRAKASH A</td><td align="left">Independent</td><td>164</td><td>3</td><td>167</td><td>0.11</td></tr> <tr><td>6</td><td align="left">THANGAPPAN C</td><td align="left">Independent</td><td>105</td><td>5</td><td>110</td><td>0.07</td></tr> <tr><td>7</td><td align="left">MANAVAI KANNAN M</td><td align="left">Independent</td><td>175</td><td>3</td><td>178</td><td>0.11</td></tr> <tr><td>8</td><td align="left">MOHAN KUMAR M</td><td align="left">Independent</td><td>609</td><td>8</td><td>617</td><td>0.39</td></tr> <tr><td>9</td><td align="left">VIJAYA KUMAR C</td><td align="left">Independent</td><td>142</td><td>2</td><td>144</td><td>0.09</td></tr> <tr><td>10</td><td align="left">SHAJIN R</td><td align="left">Independent</td><td>285</td><td>5</td><td>290</td><td>0.18</td></tr> <tr><td>11</td><td align="left">NOTA</td><td align="left">None of the Above</td><td>892</td><td>27</td><td>919</td><td>0.58</td></tr>
# </tbody>
# <tfoot>
# <tr>
# <th></th>
# <th style="text-align: left;">Total</th>
# <th> </th>
# <th>154874</th>
# <th>2902</th>
# <th>157776</th>
# <th></th>
# </tr>
# </tfoot>
# </table>

# %%
table_title = soup.find_all('th')
table_title
# Out:
# [<th>S.N.</th>,
#  <th style="text-align: left;">Candidate</th>,
#  <th style="text-align: left;">Party</th>,
#  <th>EVM Votes </th>,
#  <th>Postal Votes</th>,
#  <th>Total Votes</th>,
#  <th>% of Votes</th>,
#  <th></th>,
#  <th style="text-align: left;">Total</th>,
#  <th> </th>,
#  <th>154874</th>,
#  <th>2902</th>,
#  <th>157776</th>,
#  <th></th>]

# %%
Full_table_title = ['S.N0.', 'Candidate', 'Party', 'EVM Votes', 'Postal Votes', 'Total Votes', '% of Votes']

# Elements to remove
unwanted_elements = ['', 'Total', '137186', '621', '137807']

# Filter out unwanted elements
filtered_titles = [title for title in Full_table_title if title not in unwanted_elements]

print(filtered_titles)
# Out:
# ['S.N0.', 'Candidate', 'Party', 'EVM Votes', 'Postal Votes', 'Total Votes', '% of Votes']

# %%
import pandas as pd
from bs4 import BeautifulSoup

# Step 1: Define the filtered column titles
Full_table_title = ['S.N.', 'Candidate', 'Party', 'EVM Votes', 'Postal Votes', 'Total Votes', '% of Votes']

# Step 2: Create the DataFrame with the filtered column titles
df = pd.DataFrame(columns=Full_table_title)

# Step 3: Find all table rows
column_data = soup.find_all('tr')

# Step 4: Iterate over each row and extract data
for row in column_data[1:]:  # Skipping the header row
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    # Ensure the row has the correct number of elements before appending
    if len(individual_row_data) == len(Full_table_title):
        df.loc[len(df)] = individual_row_data

# %%
df
# Out:
#    S.N.          Candidate                                     Party  \
# 0     1  THARAHAI CUTHBERT                  Indian National Congress
# 1     2       NANTHINI V S                    Bharatiya Janata Party
# 2     3             RANI U  All India Anna Dravida Munnetra Kazhagam
# 3     4           JEMINI R                       Naam Tamilar Katchi
# 4     5       OM PRAKASH A                               Independent
# 5     6       THANGAPPAN C                               Independent
# 6     7   MANAVAI KANNAN M                               Independent
# 7     8      MOHAN KUMAR M                               Independent
# 8     9     VIJAYA KUMAR C                               Independent
# 9    10           SHAJIN R                               Independent
# 10   11               NOTA                         None of the Above
#
#    EVM Votes Postal Votes Total Votes % of Votes
# 0      89387         1667       91054      57.71
# 1      50008          872       50880      32.25
# 2       5178           89        5267       3.34
# 3       7929          221        8150       5.17
# 4        164            3         167       0.11
# 5        105            5         110       0.07
# 6        175            3         178       0.11
# 7        609            8         617       0.39
# 8        142            2         144       0.09
# 9        285            5         290       0.18
# 10       892           27         919       0.58

# %%
df.to_csv('TamilNadu.csv', index=False)
